# %% [markdown]
# # Original research data overview
#
# Overview of the original research data extracted from [World Happiness Report 2021](https://worldhappiness.report/ed/2021/). The attributes definition can be found [here](https://happiness-report.s3.amazonaws.com/2021/Appendix1WHR2021C2.pdf).

# %% [markdown]
# ## Preparing the environment

# %%
import pandas as pd

# %%
base_repository = '../data/original'

# %% [markdown]
# ## Loading the data

# %%
past_data = pd.read_excel(base_repository + '/HistoricData.xls')
past_data.head()
# Out:
#   Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0  Afghanistan  2008     3.723590            7.370100        0.450662
# 1  Afghanistan  2009     4.401778            7.539972        0.552308
# 2  Afghanistan  2010     4.758381            7.646709        0.539075
# 3  Afghanistan  2011     3.831719            7.619532        0.521104
# 4  Afghanistan  2012     3.782938            7.705479        0.520637
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity  \
# 0                         50.799999                      0.718114    0.167640
# 1                         51.200001                      0.678896    0.190099
# 2                         51.599998                      0.600127    0.120590
# 3                         51.919998                      0.495901    0.162427
# 4                         52.240002                      0.530935    0.236032
#
#    Perceptions of corruption  Positive affect  Negative affect
# ...

# %%
data_2021 = pd.read_excel(base_repository + '/Data_2021.xls')
data_2021.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe        7.8421
# 1      Denmark     Western Europe        7.6195
# 2  Switzerland     Western Europe        7.5715
# 3      Iceland     Western Europe        7.5539
# 4  Netherlands     Western Europe        7.4640
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                        0.031646      7.904126      7.780075
# 1                        0.034657      7.687428      7.551572
# 2                        0.036243      7.642536      7.500463
# 3                        0.059373      7.670271      7.437528
# 4                        0.027326      7.517559      7.410441
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0              10.775202        0.953603                72.000000
# 1              10.933176        0.954410                72.699753
# 2              11.117368        0.941742                74.400101
# ...

# %% [markdown]
# ## Data Analysis

# %%
past_data.describe()
# Out:
#               year  Life Ladder  Log GDP per capita  Social support  \
# count  1949.000000  1949.000000         1913.000000     1936.000000
# mean   2013.216008     5.466707            9.368459        0.812553
# std       4.166828     1.115717            1.154091        0.118480
# min    2005.000000     2.375092            6.635322        0.290184
# 25%    2010.000000     4.640079            8.463744        0.749390
# 50%    2013.000000     5.386025            9.460323        0.835167
# 75%    2017.000000     6.283498           10.352778        0.905291
# max    2020.000000     8.018934           11.648169        0.987343
#
#        Healthy life expectancy at birth  Freedom to make life choices  \
# count                       1894.000000                   1917.000000
# mean                          63.359375                      0.742567
# std                            7.510244                      0.142104
# min                           32.299999                      0.257534
# ...

# %%
data_2021.describe()
# Out:
#        Ladder score  Standard error of ladder score  upperwhisker  \
# count    149.000000                      149.000000    149.000000
# mean       5.532832                        0.058764      5.648008
# std        1.073923                        0.022011      1.054320
# min        2.522900                        0.025583      2.596468
# 25%        4.851800                        0.043369      4.991074
# 50%        5.533500                        0.054181      5.624688
# 75%        6.255400                        0.069863      6.344270
# max        7.842100                        0.172664      7.904126
#
#        lowerwhisker  Logged GDP per capita  Social support  \
# count    149.000000             149.000000      149.000000
# mean       5.417655               9.432209        0.814726
# std        1.094875               1.158585        0.114892
# min        2.449332               6.635322        0.462596
# 25%        4.705666               8.540956        0.749777
# ...
